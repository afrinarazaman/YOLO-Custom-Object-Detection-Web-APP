# %%
import os
from glob import glob
import pandas as pd
from functools import reduce
from xml.etree import ElementTree as et

# %%
xml_files = glob('/home/afrin/workspace/object_detection/notes/data_images/**/*.xml', recursive=True)

# %%
xml_files
# Out:
# ['/home/afrin/workspace/object_detection/notes/data_images/data_images/002369.xml',
#  '/home/afrin/workspace/object_detection/notes/data_images/data_images/005674.xml',
#  '/home/afrin/workspace/object_detection/notes/data_images/data_images/007586.xml',
#  '/home/afrin/workspace/object_detection/notes/data_images/data_images/001457.xml',
#  '/home/afrin/workspace/object_detection/notes/data_images/data_images/008301.xml',
#  '/home/afrin/workspace/object_detection/notes/data_images/data_images/009830.xml',
#  '/home/afrin/workspace/object_detection/notes/data_images/data_images/009037.xml',
#  '/home/afrin/workspace/object_detection/notes/data_images/data_images/000977.xml',
#  '/home/afrin/workspace/object_detection/notes/data_images/data_images/002664.xml',
#  '/home/afrin/workspace/object_detection/notes/data_images/data_images/002279.xml',
#  '/home/afrin/workspace/object_detection/notes/data_images/data_images/002328.xml',
# ...

# %%
tree = et.parse('/home/afrin/workspace/object_detection/notes/data_images/data_images/002369.xml')
root = tree.getroot()
root
# Out:
# <Element 'annotation' at 0x7f9170e77010>

# %%
image_name = root.find('filename').text
# Out:
# '002369.jpg'

# %%
width = root.find('size').find('width').text
width
# Out:
# '500'

# %%
height = root.find('size').find('height').text

# %%
objects = root.findall('object')
objects
# Out:
# [<Element 'object' at 0x7f91705b22f0>]

# %%
obj = objects[0]
name = obj.find('name').text
bndbox = obj.find('bndbox')
xmin = bndbox.find('xmin').text
xmax = bndbox.find('xmax').text
ymin = bndbox.find('ymin').text
ymax = bndbox.find('ymax').text
[name, xmin, xmax, ymin, ymax]
# Out:
# ['cow', '138', '215', '135', '232']

# %%
tree = et.parse('/home/afrin/workspace/object_detection/notes/data_images/data_images/000002.xml')
root = tree.getroot()

image_name = root.find('filename').text

width = root.find('size').find('width').text
height = root.find('size').find('height').text

objs = root.findall('object')

parser = []
for obj in objs:
    name = obj.find('name').text
    bndbox = obj.find('bndbox')
    xmin = bndbox.find('xmin').text
    xmax = bndbox.find('xmax').text
    ymin = bndbox.find('ymin').text
    ymax = bndbox.find('ymax').text
    parser.append([image_name, width, height, name,xmin,xmax,ymin,ymax])

print(parser)
# Out:
# [['000002.jpg', '800', '600', 'car', '41', '768', '240', '497'], ['000002.jpg', '800', '600', 'car', '533', '722', '236', '299']]

# %%
def extract_text(filename):
    
    tree = et.parse(filename)
    root = tree.getroot()

    image_name = root.find('filename').text
  
    width = root.find('size').find('width').text
    height = root.find('size').find('height').text
    
    objs = root.findall('object')
    
    parser = []
    for obj in objs:
        name = obj.find('name').text
        bndbox = obj.find('bndbox')
        xmin = bndbox.find('xmin').text
        xmax = bndbox.find('xmax').text
        ymin = bndbox.find('ymin').text
        ymax = bndbox.find('ymax').text
        parser.append([image_name, width, height, name,xmin,xmax,ymin,ymax])
        
    return parser

# %%
parser_all = list(map(extract_text,xml_files))

# %%
parser_all
# Out:
# [[['002369.jpg', '500', '375', 'cow', '138', '215', '135', '232']],
#  [['005674.jpg', '360', '480', 'bird', '10', '288', '63', '476']],
#  [['007586.jpg', '500', '375', 'train', '1', '241', '145', '248'],
#   ['007586.jpg', '500', '375', 'person', '434', '448', '222', '253'],
#   ['007586.jpg', '500', '375', 'person', '320', '329', '209', '245'],
#   ['007586.jpg', '500', '375', 'person', '290', '298', '204', '234'],
#   ['007586.jpg', '500', '375', 'person', '280', '286', '203', '231'],
#   ['007586.jpg', '500', '375', 'person', '271', '281', '217', '234']],
#  [['001457.jpg', '500', '375', 'sofa', '136', '350', '121', '264'],
#   ['001457.jpg', '500', '375', 'chair', '432', '500', '212', '375']],
#  [['008301.jpg', '375', '500', 'person', '153', '375', '191', '500']],
#  [['009830.jpg', '500', '375', 'car', '43', '401', '18', '315']],
#  [['009037.jpg', '500', '375', 'bus', '325', '500', '166', '257']],
#  [['000977.jpg', '500', '333', 'car', '149', '179', '271', '295'],
# ...

# %%
data = reduce(lambda x, y : x+y,parser_all)

# %%
df = pd.DataFrame(data,columns = ['filename','width','height','name','xmin','xmax','ymin','ymax'])

# %%
df.head()
# Out:
#      filename width height    name xmin xmax ymin ymax
# 0  002369.jpg   500    375     cow  138  215  135  232
# 1  005674.jpg   360    480    bird   10  288   63  476
# 2  007586.jpg   500    375   train    1  241  145  248
# 3  007586.jpg   500    375  person  434  448  222  253
# 4  007586.jpg   500    375  person  320  329  209  245

# %%
df.shape
# Out:
# (15663, 8)

# %%
df['name'].value_counts()
# Out:
# name
# person         5447
# car            1650
# chair          1427
# bottle          634
# pottedplant     625
# bird            599
# dog             538
# sofa            425
# bicycle         418
# horse           406
# boat            398
# motorbike       390
# cat             389
# tvmonitor       367
# cow             356
# sheep           353
# aeroplane       331
# train           328
# diningtable     310
# bus             272
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15663 entries, 0 to 15662
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  15663 non-null  object
#  1   width     15663 non-null  object
#  2   height    15663 non-null  object
#  3   name      15663 non-null  object
#  4   xmin      15663 non-null  object
#  5   xmax      15663 non-null  object
#  6   ymin      15663 non-null  object
#  7   ymax      15663 non-null  object
# dtypes: object(8)
# memory usage: 979.1+ KB

# %%
cols = ['width','height','xmin','xmax','ymin','ymax']
df[cols] = df[cols].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15663 entries, 0 to 15662
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  15663 non-null  object
#  1   width     15663 non-null  int64
#  2   height    15663 non-null  int64
#  3   name      15663 non-null  object
#  4   xmin      15663 non-null  int64
#  5   xmax      15663 non-null  int64
#  6   ymin      15663 non-null  int64
#  7   ymax      15663 non-null  int64
# dtypes: int64(6), object(2)
# memory usage: 979.1+ KB

# %%
df['center_x'] = ((df['xmax']+df['xmin'])/2)/df['width']
df['center_y'] = ((df['ymax']+df['ymin'])/2)/df['height']

# %%
df['w'] = (df['xmax']-df['xmin'])/df['width']
df['h'] = (df['ymax']-df['ymin'])/df['height']

# %%
df.head()
# Out:
#      filename  width  height    name  xmin  xmax  ymin  ymax  center_x  \
# 0  002369.jpg    500     375     cow   138   215   135   232  0.353000
# 1  005674.jpg    360     480    bird    10   288    63   476  0.413889
# 2  007586.jpg    500     375   train     1   241   145   248  0.242000
# 3  007586.jpg    500     375  person   434   448   222   253  0.882000
# 4  007586.jpg    500     375  person   320   329   209   245  0.649000
#
#    center_y         w         h
# 0  0.489333  0.154000  0.258667
# 1  0.561458  0.772222  0.860417
# 2  0.524000  0.480000  0.274667
# 3  0.633333  0.028000  0.082667
# 4  0.605333  0.018000  0.096000

# %%
images = df['filename']
images
# Out:
# 0        002369.jpg
# 1        005674.jpg
# 2        007586.jpg
# 3        007586.jpg
# 4        007586.jpg
#             ...
# 15658    005952.jpg
# 15659    005952.jpg
# 15660    009867.jpg
# 15661    009867.jpg
# 15662    009867.jpg
# Name: filename, Length: 15663, dtype: object

# %%
images = df['filename'].unique()

# %%
images
# Out:
# array(['002369.jpg', '005674.jpg', '007586.jpg', ..., '006501.jpg',
#        '005952.jpg', '009867.jpg'], shape=(5012,), dtype=object)

# %%
len(images)
# Out:
# 5012

# %%
img_df = pd.DataFrame(images,columns=['filename'])
img_df
# Out:
#         filename
# 0     002369.jpg
# 1     005674.jpg
# 2     007586.jpg
# 3     001457.jpg
# 4     008301.jpg
# ...          ...
# 5007  000620.jpg
# 5008  007618.jpg
# 5009  006501.jpg
# 5010  005952.jpg
# 5011  009867.jpg
#
# [5012 rows x 1 columns]

# %%
img_train = tuple(img_df.sample(frac=0.8)['filename'])

# %%
img_train
# Out:
# ('000417.jpg',
#  '006971.jpg',
#  '006748.jpg',
#  '002668.jpg',
#  '008931.jpg',
#  '003229.jpg',
#  '009389.jpg',
#  '000180.jpg',
#  '001807.jpg',
#  '007803.jpg',
#  '007914.jpg',
#  '003466.jpg',
#  '006018.jpg',
#  '007270.jpg',
#  '008229.jpg',
#  '008151.jpg',
#  '006638.jpg',
#  '009532.jpg',
#  '008370.jpg',
#  '002054.jpg',
#  '006355.jpg',
#  '006637.jpg',
#  '003848.jpg',
#  '007241.jpg',
#  '006066.jpg',
#  '003450.jpg',
#  '006625.jpg',
#  '007419.jpg',
#  '008748.jpg',
#  '004600.jpg',
#  '006673.jpg',
#  '004673.jpg',
#  '009136.jpg',
#  '003027.jpg',
#  '007092.jpg',
#  '006350.jpg',
#  '001293.jpg',
#  '007919.jpg',
#  '002796.jpg',
#  '009773.jpg',
#  '005236.jpg',
#  '008653.jpg',
#  '005391.jpg',
#  '000862.jpg',
#  '002986.jpg',
#  '004141.jpg',
#  '004315.jpg',
#  '005457.jpg',
#  '002497.jpg',
#  '004796.jpg',
#  '000298.jpg',
#  '003044.jpg',
#  '009841.jpg',
#  '009949.jpg',
#  '007148.jpg',
#  '005723.jpg',
#  '006664.jpg',
#  '004528.jpg',
# ...

# %%
img_test = tuple(img_df.query(f'filename not in {img_train}')['filename'])

# %%
len(img_train), len(img_test)
# Out:
# (4010, 1002)

# %%
train_df = df.query(f'filename in {img_train}')
test_df = df.query(f'filename in {img_test}')

# %%
train_df.head()
# Out:
#      filename  width  height    name  xmin  xmax  ymin  ymax  center_x  \
# 0  002369.jpg    500     375     cow   138   215   135   232     0.353
# 2  007586.jpg    500     375   train     1   241   145   248     0.242
# 3  007586.jpg    500     375  person   434   448   222   253     0.882
# 4  007586.jpg    500     375  person   320   329   209   245     0.649
# 5  007586.jpg    500     375  person   290   298   204   234     0.588
#
#    center_y      w         h
# 0  0.489333  0.154  0.258667
# 2  0.524000  0.480  0.274667
# 3  0.633333  0.028  0.082667
# 4  0.605333  0.018  0.096000
# 5  0.584000  0.016  0.080000

# %%
test_df.head()
# Out:
#       filename  width  height   name  xmin  xmax  ymin  ymax  center_x  \
# 1   005674.jpg    360     480   bird    10   288    63   476  0.413889
# 34  005318.jpg    500     375    car   109   421    37   291  0.530000
# 36  000581.jpg    500     332  sheep   140   272   184   292  0.412000
# 73  000024.jpg    500     335  train   196   489   165   247  0.685000
# 74  008442.jpg    500     375    cat   231   387    70   221  0.618000
#
#     center_y         w         h
# 1   0.561458  0.772222  0.860417
# 34  0.437333  0.624000  0.677333
# 36  0.716867  0.264000  0.325301
# 73  0.614925  0.586000  0.244776
# 74  0.388000  0.312000  0.402667

# %%
def label_encoding(x):
    labels = {'person':0, 'car':1, 'chair':2, 'bottle':3, 'pottedplant':4, 'bird':5, 'dog':6,
       'sofa':7, 'bicycle':8, 'horse':9, 'boat':10, 'motorbike':11, 'cat':12, 'tvmonitor':13,
       'cow':14, 'sheep':15, 'aeroplane':16, 'train':17, 'diningtable':18, 'bus':19}
    return labels[x]

# %%
train_df.loc[:, 'id'] = train_df['name'].apply(label_encoding)
test_df.loc[:, 'id'] = test_df['name'].apply(label_encoding)

# %%
train_df.head(10)
# Out:
#       filename  width  height    name  xmin  xmax  ymin  ymax  center_x  \
# 0   002369.jpg    500     375     cow   138   215   135   232     0.353
# 2   007586.jpg    500     375   train     1   241   145   248     0.242
# 3   007586.jpg    500     375  person   434   448   222   253     0.882
# 4   007586.jpg    500     375  person   320   329   209   245     0.649
# 5   007586.jpg    500     375  person   290   298   204   234     0.588
# 6   007586.jpg    500     375  person   280   286   203   231     0.566
# 7   007586.jpg    500     375  person   271   281   217   234     0.552
# 8   001457.jpg    500     375    sofa   136   350   121   264     0.486
# 9   001457.jpg    500     375   chair   432   500   212   375     0.932
# 10  008301.jpg    375     500  person   153   375   191   500     0.704
#
#     center_y      w         h  id
# 0   0.489333  0.154  0.258667  14
# 2   0.524000  0.480  0.274667  17
# 3   0.633333  0.028  0.082667   0
# 4   0.605333  0.018  0.096000   0
# ...

# %%
import os
from shutil import move

# %%
train_folder = '/home/afrin/workspace/object_detection/notes/data_images/train'
test_folder = '/home/afrin/workspace/object_detection/notes/data_images/test'

os.mkdir(train_folder)
os.mkdir(test_folder)

# %%
cols = ['filename','id','center_x','center_y', 'w', 'h']
groupby_obj_train = train_df[cols].groupby('filename')
groupby_obj_test = test_df[cols].groupby('filename')

# %%
def save_data(filename, folder_path, group_obj):
    # Corrected the source path
    src = os.path.join('/home/afrin/workspace/object_detection/notes/data_images/data_images', filename)
    dst = os.path.join(folder_path, filename)
    
    if not os.path.exists(src):
        print(f"Warning: {src} not found. Skipping...")
        return  # Skip missing files

    move(src, dst)
    
    text_filename = os.path.join(folder_path, os.path.splitext(filename)[0] + '.txt')
    group_obj.get_group(filename).set_index('filename').to_csv(text_filename, sep=' ', index=False, header=False)

# %%
import os
print(os.path.exists('/home/afrin/workspace/object_detection/notes/data_images/data_images/000001.jpg'))
# Out:
# True

# %%
groupby_obj_train.groups
# Out:
# {'000001.jpg': [3388, 3389, 3390, 3391], '000002.jpg': [8722, 8723], '000007.jpg': [4335], '000009.jpg': [11231, 11232, 11233, 11234], '000012.jpg': [5491], '000016.jpg': [13488], '000019.jpg': [11669, 11670], '000021.jpg': [13552, 13553, 13554, 13555], '000023.jpg': [3489, 3490, 3491, 3492, 3493, 3494], '000030.jpg': [9885, 9886, 9887], '000032.jpg': [12113, 12114, 12115, 12116], '000033.jpg': [11201, 11202, 11203], '000034.jpg': [753, 754], '000035.jpg': [2740, 2741, 2742, 2743], '000039.jpg': [10092], '000041.jpg': [14295, 14296, 14297], '000042.jpg': [14403, 14404], '000044.jpg': [13913, 13914], '000047.jpg': [11141, 11142], '000048.jpg': [12094, 12095], '000050.jpg': [2311, 2312, 2313, 2314, 2315, 2316, 2317, 2318, 2319, 2320], '000051.jpg': [12399, 12400, 12401], '000052.jpg': [5106, 5107, 5108, 5109, 5110, 5111], '000060.jpg': [13639, 13640, 13641, 13642, 13643], '000061.jpg': [3434, 3435], '000063.jpg': [6924, 6925], '000064.jpg': [7958], '000066.jpg': [5021, 5022, 5023], '00
# ...

# %%
filename_series = pd.Series(groupby_obj_train.groups.keys())

# %%
filename_series
# Out:
# 0       000001.jpg
# 1       000002.jpg
# 2       000007.jpg
# 3       000009.jpg
# 4       000012.jpg
#            ...
# 4005    009949.jpg
# 4006    009950.jpg
# 4007    009954.jpg
# 4008    009959.jpg
# 4009    009961.jpg
# Length: 4010, dtype: object

# %%
filename_series.apply(lambda x: save_data(x, train_folder, groupby_obj_train))
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 4005    None
# 4006    None
# 4007    None
# 4008    None
# 4009    None
# Length: 4010, dtype: object

# %%
filename_series_test = pd.Series(groupby_obj_test.groups.keys())
filename_series_test.apply(save_data,args=(test_folder,groupby_obj_test))
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 997     None
# 998     None
# 999     None
# 1000    None
# 1001    None
# Length: 1002, dtype: object
